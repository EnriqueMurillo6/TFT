# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import copy
from pathlib import Path
import warnings
import lightning.pytorch as pl
from lightning.pytorch.callbacks import EarlyStopping, LearningRateMonitor
from lightning.pytorch.loggers import TensorBoardLogger
import numpy as np
import pandas as pd
import torch
from pytorch_forecasting import Baseline, TemporalFusionTransformer, TimeSeriesDataSet
from pytorch_forecasting.data.encoders import TorchNormalizer
from pytorch_forecasting.metrics import MAE, SMAPE, PoissonLoss, QuantileLoss
from pytorch_forecasting.models.temporal_fusion_transformer.tuning import (
    optimize_hyperparameters,
)

# %%
path_train = "/content/drive/MyDrive/TFG/Train-Test/df_train.parquet"
path_test = "/content/drive/MyDrive/TFG/Train-Test/df_test.parquet"

df_train = pd.read_parquet(path_train)
df_test = pd.read_parquet(path_test)

# %%
df_train["carb"] = df_train["carb"].fillna(0)
df_train["bolus"] = df_train["bolus"].fillna(0)
df_train["basal_rate"] = df_train["basal_rate"].ffill().bfill()

# %%
df_train["time_idx"] = (df_train["Zulu Time"] - df_train["Zulu Time"].min()).dt.total_seconds().astype(int)
df_train["time_idx"] = df_train.groupby("group_id").cumcount()

# %%
df_test["carb"] = df_test["carb"].fillna(0)
df_test["bolus"] = df_test["bolus"].fillna(0)
df_test["basal_rate"] = df_test["basal_rate"].ffill().bfill()
df_test["time_idx"] = df_test.groupby("group_id").cumcount()

# %%
from pytorch_forecasting.models import TemporalFusionTransformer

max_encoder_length = 6
max_prediction_length = 1

training = TimeSeriesDataSet(
    df_train,
    time_idx="time_idx",
    target="Value",
    group_ids=["group_id"],
    max_encoder_length=max_encoder_length,
    max_prediction_length=max_prediction_length,
    time_varying_known_reals=["time_idx", "carb", "bolus", "basal_rate"],
    time_varying_unknown_reals=["Value"]
)

# %%
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split

df_train, df_val = train_test_split(df_train, test_size=0.2, shuffle=False)

train = TimeSeriesDataSet.from_dataset(training, df_train, predict=False)
val = TimeSeriesDataSet.from_dataset(training, df_val, predict=False)

train_dataloader = train.to_dataloader(train=True, batch_size=32, num_workers=0)
val_dataloader = val.to_dataloader(train=False, batch_size=32, num_workers=0)

# %%
from pytorch_forecasting.models import TemporalFusionTransformer
from pytorch_forecasting.metrics import QuantileLoss

tft = TemporalFusionTransformer.from_dataset(
    training,
    learning_rate=1e-3,
    hidden_size=16,
    attention_head_size=1,
    dropout=0.1,
    loss=QuantileLoss(),
    log_interval=-1,
    reduce_on_plateau_patience=4,
)

# %%
from pytorch_lightning import Trainer


trainer = pl.Trainer(max_epochs=30, accelerator="gpu" if torch.cuda.is_available() else "cpu")
trainer.fit(tft, train_dataloaders=train_dataloader, val_dataloaders=val_dataloader)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:
#    | Name                               | Type                            | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | loss                               | QuantileLoss                    | 0      | train
# 1  | logging_metrics                    | ModuleList                      | 0      | train
# 2  | input_embeddings                   | MultiEmbedding                  | 0      | train
# 3  | prescalers                         | ModuleDict                      | 80     | train
# 4  | static_variable_selection          | VariableSelectionNetwork        | 0      | train
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 3.0 K  | train
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 2.4 K  | train
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 1.1 K  | train
# 10 | static_context_enrichment          | GatedResidualNetwork            | 1.1 K  | train
# 11 | lstm_encoder                       | LSTM                            | 2.2 K  | train
# 12 | lstm_decoder                       | LSTM                            | 2.2 K  | train
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 544    | train
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 32     | train
# 15 | static_enrichment                  | GatedResidualNetwork            | 1.4 K  | train
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 1.1 K  | train
# 17 | post_attn_gate_norm                | GateAddNorm                     | 576    | train
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 1.1 K  | train
# 19 | pre_output_gate_norm               | GateAddNorm                     | 576    | train
# 20 | output_layer                       | Linear                          | 119    | train
# ------------------------------------------------------------------------------------------------
# 19.6 K    Trainable params
# 0         Non-trainable params
# 19.6 K    Total params
# 0.078     Total estimated model params size (MB)
# 272       Modules in train mode
# 0         Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#    | Name                               | Type                            | Params | Mode
# ------------------------------------------------------------------------------------------------
# 0  | loss                               | QuantileLoss                    | 0      | train
# 1  | logging_metrics                    | ModuleList                      | 0      | train
# 2  | input_embeddings                   | MultiEmbedding                  | 0      | train
# 3  | prescalers                         | ModuleDict                      | 80     | train
# 4  | static_variable_selection          | VariableSelectionNetwork        | 0      | train
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 3.0 K  | train
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 2.4 K  | train
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 1.1 K  | train
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 1.1 K  | train
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 1.1 K  | train
# 10 | static_context_enrichment          | GatedResidualNetwork            | 1.1 K  | train
# 11 | lstm_encoder                       | LSTM                            | 2.2 K  | train
# 12 | lstm_decoder                       | LSTM                            | 2.2 K  | train
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 544    | train
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 32     | train
# 15 | static_enrichment                  | GatedResidualNetwork            | 1.4 K  | train
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 1.1 K  | train
# 17 | post_attn_gate_norm                | GateAddNorm                     | 576    | train
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 1.1 K  | train
# 19 | pre_output_gate_norm               | GateAddNorm                     | 576    | train
# 20 | output_layer                       | Linear                          | 119    | train
# ------------------------------------------------------------------------------------------------
# 19.6 K    Trainable params
# 0         Non-trainable params
# 19.6 K    Total params
# 0.078     Total estimated model params size (MB)
# 272       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      47             return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 48         return trainer_fn(*args, **kwargs)
#      49
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py in _fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     598         )
# --> 599         self._run(model, ckpt_path=ckpt_path)
#     600
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py in _run(self, model, ckpt_path)
#    1011         # ----------------------------
# -> 1012         results = self._run_stage()
#    1013
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py in _run_stage(self)
#    1055             with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1056                 self.fit_loop.run()
#    1057             return None
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py in run(self)
#     215                 self.on_advance_start()
# --> 216                 self.advance()
#     217                 self.on_advance_end()
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py in advance(self)
#     454             assert self._data_fetcher is not None
# --> 455             self.epoch_loop.run(self._data_fetcher)
#     456
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py in run(self, data_fetcher)
#     149             try:
# --> 150                 self.advance(data_fetcher)
#     151                 self.on_advance_end(data_fetcher)
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py in advance(self, data_fetcher)
#     319                     # in automatic optimization, there can only be one optimizer
# --> 320                     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#     321                 else:
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/optimization/automatic.py in run(self, optimizer, batch_idx, kwargs)
#     191         else:
# --> 192             self._optimizer_step(batch_idx, closure)
#     193
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/optimization/automatic.py in _optimizer_step(self, batch_idx, train_step_and_backward_closure)
#     269         # model hook
# --> 270         call._call_lightning_module_hook(
#     271             trainer,
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py in _call_lightning_module_hook(trainer, hook_name, pl_module, *args, **kwargs)
#     175     with trainer.profiler.profile(f"[LightningModule]{pl_module.__class__.__name__}.{hook_name}"):
# --> 176         output = fn(*args, **kwargs)
#     177
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/core/module.py in optimizer_step(self, epoch, batch_idx, optimizer, optimizer_closure)
#    1301         """
# -> 1302         optimizer.step(closure=optimizer_closure)
#    1303
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/core/optimizer.py in step(self, closure, **kwargs)
#     153         assert self._strategy is not None
# --> 154         step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#     155
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/strategy.py in optimizer_step(self, optimizer, closure, model, **kwargs)
#     238         assert isinstance(model, pl.LightningModule)
# --> 239         return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#     240
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/plugins/precision/precision.py in optimizer_step(self, optimizer, model, closure, **kwargs)
#     122         closure = partial(self._wrap_closure, model, optimizer, closure)
# --> 123         return optimizer.step(closure=closure, **kwargs)
#     124
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     492
# --> 493                 out = func(*args, **kwargs)
#     494                 self._optimizer_step_code()
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py in _use_grad(self, *args, **kwargs)
#      90             torch._dynamo.graph_break()
# ---> 91             ret = func(self, *args, **kwargs)
#      92         finally:
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/adam.py in step(self, closure)
#     222             with torch.enable_grad():
# --> 223                 loss = closure()
#     224
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/plugins/precision/precision.py in _wrap_closure(self, model, optimizer, closure)
#     108         """
# --> 109         closure_result = closure()
#     110         self._after_closure(model, optimizer)
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/optimization/automatic.py in __call__(self, *args, **kwargs)
#     145     def __call__(self, *args: Any, **kwargs: Any) -> Optional[Tensor]:
# --> 146         self._result = self.closure(*args, **kwargs)
#     147         return self._result.loss
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/optimization/automatic.py in closure(self, *args, **kwargs)
#     130     def closure(self, *args: Any, **kwargs: Any) -> ClosureResult:
# --> 131         step_output = self._step_fn()
#     132
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/optimization/automatic.py in _training_step(self, kwargs)
#     318
# --> 319         training_step_output = call._call_strategy_hook(trainer, "training_step", *kwargs.values())
#     320         self.trainer.strategy.post_training_step()  # unused hook - call anyway for backward compatibility
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     327     with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 328         output = fn(*args, **kwargs)
#     329
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/strategy.py in training_step(self, *args, **kwargs)
#     390                 return self._forward_redirection(self.model, self.lightning_module, "training_step", *args, **kwargs)
# --> 391             return self.lightning_module.training_step(*args, **kwargs)
#     392
#
# /usr/local/lib/python3.11/dist-packages/pytorch_forecasting/models/base_model.py in training_step(self, batch, batch_idx)
#     716         x, y = batch
# --> 717         log, out = self.step(x, y, batch_idx)
#     718         self.training_step_outputs.append(log)
#
# /usr/local/lib/python3.11/dist-packages/pytorch_forecasting/models/base_model.py in step(self, x, y, batch_idx, **kwargs)
#     911         else:
# --> 912             out = self(x, **kwargs)
#     913
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#
# /usr/local/lib/python3.11/dist-packages/pytorch_forecasting/models/temporal_fusion_transformer/_tft.py in forward(self, x)
#     568         embeddings_varying_decoder, decoder_sparse_weights = (
# --> 569             self.decoder_variable_selection(
#     570                 embeddings_varying_decoder,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#
# /usr/local/lib/python3.11/dist-packages/pytorch_forecasting/models/temporal_fusion_transformer/sub_modules.py in forward(self, x, context)
#     374                 weight_inputs.append(variable_embedding)
# --> 375                 var_outputs.append(self.single_variable_grns[name](variable_embedding))
#     376             var_outputs = torch.stack(var_outputs, dim=-1)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#
# /usr/local/lib/python3.11/dist-packages/pytorch_forecasting/models/temporal_fusion_transformer/sub_modules.py in forward(self, x, context, residual)
#     269         if self.input_size != self.output_size and not self.residual:
# --> 270             residual = self.resample_norm(residual)
#     271
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#
# /usr/local/lib/python3.11/dist-packages/pytorch_forecasting/models/temporal_fusion_transformer/sub_modules.py in forward(self, x)
#     146
# --> 147         output = self.norm(x)
#     148         return output
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/normalization.py in forward(self, input)
#     216     def forward(self, input: Tensor) -> Tensor:
# --> 217         return F.layer_norm(
#     218             input, self.normalized_shape, self.weight, self.bias, self.eps
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py in layer_norm(input, normalized_shape, weight, bias, eps)
#    2909         )
# -> 2910     return torch.layer_norm(
#    2911         input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-3c41bf73bc1c> in <cell line: 0>()
#       3
#       4 trainer = pl.Trainer(max_epochs=30, accelerator="gpu" if torch.cuda.is_available() else "cpu")
# ----> 5 trainer.fit(tft, train_dataloaders=train_dataloader, val_dataloaders=val_dataloader)
#       6
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py in fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     559         self.training = True
#     560         self.should_stop = False
# --> 561         call._call_and_handle_interrupt(
#     562             self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     563         )
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      63         if isinstance(launcher, _SubprocessScriptLauncher):
#      64             launcher.kill(_get_sigkill_signal())
# ---> 65         exit(1)
#      66
#      67     except BaseException as exception:
#
# NameError: name 'exit' is not defined
